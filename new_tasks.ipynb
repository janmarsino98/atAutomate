# %%
import requests
from dotenv import load_dotenv
import os

url = "https://www.airtasker.com/api/v2/tasks?limit=50&path=tasks&threaded_comments=true&task_states=posted&after=0&task_types=online&radius=50000&carl_ids=&disable_recommendations=false&badges=&max_price=9999&min_price=5&sort_by=posted_desc&save_filters=true"

load_dotenv()
proxy_cred = os.getenv("HTTP_PROXY")
proxy = {
    "http": f"http://{proxy_cred}",
    "https": f"http://{proxy_cred}",
}

HEADERS = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
    }
try:
    # Making the GET request
    r = requests.get(url, headers=HEADERS, proxies=proxy)
    
    # Raise an exception if the status code indicates an error
    r.raise_for_status()
    
    # Parse the response as JSON
    data = r.json()
    print(data)  # Or process the data as needed
    
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")  # Handle HTTP errors
except Exception as err:
    print(f"An error occurred: {err}")  # Handle any other errors
# Out:
# {'locations': [{'id': 1283645, 'latitude': '-31.800824', 'longitude': '115.773385', 'display_name': 'Padbury WA, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 881912, 'latitude': '-37.917809', 'longitude': '144.747726', 'display_name': 'Point Cook VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1473511, 'latitude': '-33.902561', 'longitude': '151.254807', 'display_name': 'Waverley NSW, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1126342, 'latitude': '-27.535467', 'longitude': '153.197125', 'display_name': 'Capalaba QLD, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 686217, 'latitude': '-37.794659', 'longitude': '145.084869', 'display_name': 'Balwyn North VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 400608, 'latitude': '-27.4802', 'longitude': '153.012207', 'display_name': 'West End QLD, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 707877, 'latitude': '-37.683583', 'longitude': '144.577951', 'display_name': 'Melton VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 2006330, 'latitude': '-27.920837', 'longitude': '153.321777', 'display_name': 'Oxenford QLD, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 698006, 'latitude': '-38.146625', 'longitude': '145.135722', 'display_name': 'Frankston VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 375280, 'latitude': '-37.553', 'longitude': '143.771', 'display_name': 'Lucas VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 406893, 'latitude': '-38.105', 'longitude': '145.279', 'display_name': 'Cranbourne VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 361608, 'latitude': '-37.829', 'longitude': '144.957', 'display_name': 'Southbank VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1403810, 'latitude': '-37.529439', 'longitude': '144.959548', 'display_name': 'Kalkallo VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1357422, 'latitude': '-33.853779', 'longitude': '150.985256', 'display_name': 'Guildford NSW, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 58213, 'latitude': '-31.953596', 'longitude': '115.857012', 'display_name': 'Perth WA, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1282757, 'latitude': '-32.221722', 'longitude': '116.007339', 'display_name': 'Byford WA, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1236932, 'latitude': '-12.463734', 'longitude': '130.844452', 'display_name': 'Darwin NT, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1398410, 'latitude': '-37.593983', 'longitude': '144.910032', 'display_name': 'Craigieburn VIC, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 45945, 'latitude': '-37.814563', 'longitude': '144.970267', 'display_name': 'Melbourne, VIC', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 147105, 'latitude': '-37.813611', 'longitude': '144.963056', 'display_name': 'Melbourne VIC 3004, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1398050, 'latitude': '-34.928497', 'longitude': '138.600739', 'display_name': 'Adelaide SA, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1105095, 'latitude': '-27.553142', 'longitude': '152.973894', 'display_name': 'Oxley QLD, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 147828, 'latitude': '-34.928499', 'longitude': '138.600746', 'display_name': 'Adelaide SA, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1133006, 'latitude': '-33.907256', 'longitude': '151.207706', 'display_name': 'Zetland NSW, Australia', 'canonical_location_id': None, 'alpha_2_code': None}, {'id': 1893682, 'latitude': '-31.951399', 'long ...

# %%
created_at = data["tasks"][0]["created_at"]
publisher_id = data["tasks"][0]["sender_id"]
for profile in data["profiles"]:
    if profile["id"] == publisher_id:
        publisher_abbreviated_name = profile["abbreviated_name"]
        publisher_last_activity_at = profile["last_activity_at"]
# Out:
# '2024-10-15T07:56:20+11:00'

# %%
# Out:
# 8155237

# %%
# Out:
# dict_keys(['statistics_data_updated_at', 'average_rating', 'comments_count', 'allow_calls_on_tasks', 'default_location_id', 'id', 'first_name', 'avatar', 'abbreviated_name', 'slug', 'pro', 'posted_tasks_count', 'run_tasks_count', 'received_reviews_count', 'ranking_position', 'ranking', 'active', 'supertasker', 'posted_task_statistics', 'run_task_statistics', 'sender_review_statistics', 'runner_review_statistics', 'last_activity_at'])

# %%
data["tasks"][0]["slug"]
# Out:
# 'resume-and-cover-letter-x01ja6d2kw9wwf5gwhzjhp88gcp'
